# %% [markdown]
# # **Regressão com Árvores de Decisão**

# %% [markdown]
# A regressão retorna valores numéricos, ao contrário da classificação. A árvore de decisão para regressão opera da mesma forma que a da classificação mas, aqui, ele retorna um valor médio contido no conjunto de dados de cada split.

# %%
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
base_plano_saude2 = pd.read_csv('/Users/gustavomeira/Documents/Python/Estudo_ML/projects/Regressão/plano_saude2.csv')
base_casas = pd.read_csv('/Users/gustavomeira/Documents/Python/Estudo_ML/projects/Regressão/house_prices.csv')

# %%
from sklearn.tree import DecisionTreeRegressor

X_plano_saude2 = base_plano_saude2.iloc[:,0:1].values
Y_plano_saude2 = base_plano_saude2.iloc[:,1].values

regressor_arvore_saude = DecisionTreeRegressor()
regressor_arvore_saude.fit(X_plano_saude2, Y_plano_saude2)
previsoes = regressor_arvore_saude.predict(X_plano_saude2)

# %%
print(regressor_arvore_saude.score(X_plano_saude2, Y_plano_saude2))
grafico = px.scatter(x=X_plano_saude2.ravel(), y=Y_plano_saude2)
grafico.add_scatter(x=X_plano_saude2.ravel(), y=previsoes, name='Regressão')
grafico.show()
# Out:
# 1.0

# %%
X_teste_arvore = np.arange(min(X_plano_saude2), max(X_plano_saude2), 0.1);
# print(X_teste_arvore);
X_teste_arvore = X_teste_arvore.reshape(-1,1)
print(regressor_arvore_saude.score(X_plano_saude2, Y_plano_saude2))
grafico = px.scatter(x=X_plano_saude2.ravel(), y=Y_plano_saude2)
grafico.add_scatter(x=X_teste_arvore.ravel(), y=regressor_arvore_saude.predict(X_teste_arvore), name='Regressão')
grafico.show()
# Out:
# 1.0
# /var/folders/nt/5c9y96096y722j4fgxzpzkc00000gn/T/ipykernel_12885/4107440537.py:1: DeprecationWarning:
#
# Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)

# %%
from sklearn.model_selection import train_test_split

X_casas = base_casas.iloc[:,3:19].values
Y_casas = base_casas.iloc[:,2].values

X_casas_treinamento, X_casas_teste, Y_casas_treinamento, Y_casas_teste = train_test_split(X_casas, Y_casas, test_size=0.3, random_state=0)

# %%
regressor_arvore_casas = DecisionTreeRegressor()
regressor_arvore_casas.fit(X_casas_treinamento, Y_casas_treinamento)
print('score =',regressor_arvore_casas.score(X_casas_treinamento, Y_casas_treinamento))
print('score =',regressor_arvore_casas.score(X_casas_teste, Y_casas_teste))
# Out:
# score = 0.9992712177726063
# score = 0.7515747431243646

# %%
from sklearn.metrics import mean_absolute_error

previsoes = regressor_arvore_casas.predict(X_casas_teste)
print(mean_absolute_error(Y_casas_teste, previsoes))
# Out:
# 99086.5217458359

# %% [markdown]
# # Floresta Randômica

# %%
from sklearn.ensemble import RandomForestRegressor

regressor_random_forest_saude = RandomForestRegressor(n_estimators=10)
regressor_random_forest_saude.fit(X_plano_saude2, Y_plano_saude2)
print(regressor_random_forest_saude.score(X_plano_saude2,Y_plano_saude2))
# Out:
# 0.9757020511150408

# %%
X_teste_arvore = np.arange(min(X_plano_saude2), max(X_plano_saude2), 0.1);
# print(X_teste_arvore);
X_teste_arvore = X_teste_arvore.reshape(-1,1)
print(regressor_arvore_saude.score(X_plano_saude2, Y_plano_saude2))
grafico = px.scatter(x=X_plano_saude2.ravel(), y=Y_plano_saude2)
grafico.add_scatter(x=X_teste_arvore.ravel(), y=regressor_random_forest_saude.predict(X_teste_arvore), name='Regressão')
grafico.show()
# Out:
# /var/folders/nt/5c9y96096y722j4fgxzpzkc00000gn/T/ipykernel_12885/2307259024.py:1: DeprecationWarning:
#
# Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
# 1.0

# %%
regressor_random_forest_casas = RandomForestRegressor(n_estimators=100)
regressor_random_forest_casas.fit(X_casas_treinamento, Y_casas_treinamento)
print(regressor_random_forest_casas.score(X_casas_treinamento, Y_casas_treinamento))
print(regressor_random_forest_casas.score(X_casas_teste, Y_casas_teste))
# Out:
# 0.9813465551331626
# 0.8801448835184978

# %%
previsoes = regressor_random_forest_casas.predict(X_casas_teste)
print(mean_absolute_error(Y_casas_teste, previsoes))
# Out:
# 67727.00870013365
